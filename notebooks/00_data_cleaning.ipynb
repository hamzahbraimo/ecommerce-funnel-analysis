# %%
import pandas as pd

# %%
# details of the dataset
df = pd.read_csv('../data/ecommerce_sample.csv')

print(df.info())
print("**********")
# columns containing null values
print(df.isnull())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     500000 non-null  object
#  1   event_type     500000 non-null  object
#  2   product_id     500000 non-null  int64
#  3   category_id    500000 non-null  int64
#  4   category_code  341561 non-null  object
#  5   brand          428149 non-null  object
#  6   price          500000 non-null  float64
#  7   user_id        500000 non-null  int64
#  8   user_session   500000 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 34.3+ MB
# None
# **********
#         event_time  event_type  product_id  category_id  category_code  brand  \
# 0            False       False       False        False           True  False
# 1            False       False       False        False          False  False
# 2            False       False       False        False          False   True
# 3            False       False       False        False          False  False
# 4            False       False       False        False          False  False
# ...            ...         ...         ...          ...            ...    ...
# 499995       False       False       False        False           True   True
# 499996       False       False       False        False           True   True
# 499997       False       False       False        False          False  False
# 499998       False       False       False        False          False  False
# 499999       False       False       False        False           True  False
#
#         price  user_id  user_session
# 0       False    False         False
# 1       False    False         False
# 2       False    False         False
# 3       False    False         False
# 4       False    False         False
# ...       ...      ...           ...
# 499995  False    False         False
# 499996  False    False         False
# 499997  False    False         False
# 499998  False    False         False
# 499999  False    False         False
#
# [500000 rows x 9 columns]

# %%
# DATA CLEANING
# dropping duplicates
df.drop_duplicates()

# since there are only two columns with null values, replacing them with 'unknown' value
df['category_code'] = df['category_code'].fillna('unknown')
df['brand'] = df['brand'].fillna('unknown').str.capitalize()

# adding a new column for category
df['category'] = df['category_code'].str.split('.').str[0]

# converting the date column to datetime format
df['event_time'] = pd.to_datetime(df['event_time'].str.replace(' UTC', ''))

# checking 
df.tail()
# Out:
#                 event_time event_type  product_id          category_id  \
# 499995 2019-10-01 10:22:43       view    26400368  2053013563651392361
# 499996 2019-10-01 10:22:43       view    23300957  2053013561956893455
# 499997 2019-10-01 10:22:43       view    10900328  2053013555069845885
# 499998 2019-10-01 10:22:43       view     5701114  2053013553970938175
# 499999 2019-10-01 10:22:43       view     4100323  2053013561218695907
#
#                    category_code     brand   price    user_id  \
# 499995                   unknown   Unknown  194.86  555334137
# 499996                   unknown   Unknown   36.04  516063919
# 499997  appliances.kitchen.mixer  Dauscher   12.84  529522881
# 499998   auto.accessories.player   Prology   25.74  516810731
# 499999                   unknown      Sony  729.47  512788178
#
#                                 user_session    category
# 499995  c74f934a-0713-4a75-a670-1e776c02192d     unknown
# 499996  e8872734-9d35-4c12-92e0-01452dc2635f     unknown
# 499997  c21547fb-d417-4096-bba1-60582f4732a0  appliances
# 499998  d7ecd02e-f15f-4f7a-8e43-07e6db9e717d        auto
# 499999  65a0f179-7d0a-4bd4-bb41-581e1206e688     unknown

# %%
# checking info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     500000 non-null  datetime64[ns]
#  1   event_type     500000 non-null  object
#  2   product_id     500000 non-null  int64
#  3   category_id    500000 non-null  int64
#  4   category_code  500000 non-null  object
#  5   brand          500000 non-null  object
#  6   price          500000 non-null  float64
#  7   user_id        500000 non-null  int64
#  8   user_session   500000 non-null  object
#  9   category       500000 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 38.1+ MB

# %%
# SAVING
# saving the clean data
df.to_csv('../data/ecommerce_sample_clean.csv', index=False)
